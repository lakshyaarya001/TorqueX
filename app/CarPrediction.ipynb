# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
data = pd.read_csv('cleaned_car.csv')

# %%
data.head()
# Out:
#            Brand     model  Year  Age  kmDriven Transmission   Owner FuelType  \
# 0     Volkswagen      Polo  2021    3         1       Manual  second   Petrol
# 1  Maruti Suzuki    Baleno  2018    6         1       Manual  second   Petrol
# 2        Hyundai     Verna  2016    8         1       Manual  second   Diesel
# 3           Audi        A4  2012   12         1    Automatic  second   Diesel
# 4         Toyota  Fortuner  2011   13         1       Manual  second   Diesel
#
#      Price
# 0   675000
# 1   630000
# 2   465000
# 3   899000
# 4  1125000

# %%
data.tail()
# Out:
#                Brand       model  Year  Age  kmDriven Transmission   Owner  \
# 14859       Mahindra      XUV500  2020    4    950000    Automatic   first
# 14860        Hyundai  i20 Active  2015    9    950000       Manual   first
# 14861  Maruti Suzuki     Wagon-R  2012   12    950000       Manual  second
# 14862        Hyundai   Grand i10  2018    6    980000       Manual   first
# 14863  Maruti Suzuki      Ertiga  2013   11    980002       Manual  second
#
#          FuelType    Price
# 14859      Diesel  1350000
# 14860      Diesel   390000
# 14861  Hybrid/CNG   180000
# 14862  Hybrid/CNG   445000
# 14863  Hybrid/CNG   550000

# %%
data.shape
# Out:
# (14864, 9)

# %%
print("Number of Rows",data.shape[0])
print("Number of Columns",data.shape[1])
# Out:
# Number of Rows 14864
# Number of Columns 9

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14864 entries, 0 to 14863
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         14864 non-null  object
#  1   model         14864 non-null  object
#  2   Year          14864 non-null  int64
#  3   Age           14864 non-null  int64
#  4   kmDriven      14864 non-null  int64
#  5   Transmission  14864 non-null  object
#  6   Owner         14864 non-null  object
#  7   FuelType      14864 non-null  object
#  8   Price         14864 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 1.0+ MB

# %%
data.isnull().sum()
# Out:
# Brand           0
# model           0
# Year            0
# Age             0
# kmDriven        0
# Transmission    0
# Owner           0
# FuelType        0
# Price           0
# dtype: int64

# %%
data.describe()
# Out:
#                Year           Age       kmDriven         Price
# count  14864.000000  14864.000000   14864.000000  1.486400e+04
# mean    2016.323601      7.676399   71270.234863  9.962367e+05
# std        4.340046      4.340046   57418.837551  1.585764e+06
# min     1900.000000      0.000000       1.000000  1.500000e+04
# 25%     2014.000000      5.000000   44664.750000  3.490000e+05
# 50%     2017.000000      7.000000   65556.500000  5.700000e+05
# 75%     2019.000000     10.000000   86095.500000  1.025000e+06
# max     2024.000000    124.000000  980002.000000  4.250000e+07

# %%
data.head(1)
# Out:
#         Brand model  Year  Age  kmDriven Transmission   Owner FuelType   Price
# 0  Volkswagen  Polo  2021    3         1       Manual  second   Petrol  675000

# %%
import datetime

# %%
date_time = datetime.datetime.now()

# %%
data['Age']=date_time.year - data['Year']

# %%
data.head()
# Out:
#            Brand     model  Year  Age  kmDriven Transmission   Owner FuelType  \
# 0     Volkswagen      Polo  2021    4         1       Manual  second   Petrol
# 1  Maruti Suzuki    Baleno  2018    7         1       Manual  second   Petrol
# 2        Hyundai     Verna  2016    9         1       Manual  second   Diesel
# 3           Audi        A4  2012   13         1    Automatic  second   Diesel
# 4         Toyota  Fortuner  2011   14         1       Manual  second   Diesel
#
#      Price
# 0   675000
# 1   630000
# 2   465000
# 3   899000
# 4  1125000

# %%
data.drop('Year',axis=1,inplace=True)

# %%
data.head()
# Out:
#            Brand     model  Age  kmDriven Transmission   Owner FuelType  \
# 0     Volkswagen      Polo    4         1       Manual  second   Petrol
# 1  Maruti Suzuki    Baleno    7         1       Manual  second   Petrol
# 2        Hyundai     Verna    9         1       Manual  second   Diesel
# 3           Audi        A4   13         1    Automatic  second   Diesel
# 4         Toyota  Fortuner   14         1       Manual  second   Diesel
#
#      Price
# 0   675000
# 1   630000
# 2   465000
# 3   899000
# 4  1125000

# %%
import seaborn as sns

# %%
sns.boxplot(data['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
sns.pairplot(data)

# %%
import matplotlib.pyplot as plt

numeric_data = data.select_dtypes(include=['float64', 'int64'])
plt.figure(figsize=(18,18))
sns.heatmap(numeric_data.corr(), cmap="BuGn", annot=True)
# Out:
# <Axes: >

# %%
sorted(data['Price'],reverse=True)
# Out:
# [42500000,
#  39000000,
#  34800000,
#  30500000,
#  27750000,
#  26400000,
#  26000000,
#  24900000,
#  24700000,
#  24500000,
#  21500000,
#  18500000,
#  18500000,
#  17500000,
#  17500000,
#  17400000,
#  16500000,
#  16500000,
#  16500000,
#  16500000,
#  16500000,
#  16400000,
#  15900000,
#  15000000,
#  14900000,
#  14500000,
#  14500000,
#  14500000,
#  14000000,
#  13800000,
#  13600000,
#  13500000,
#  13300000,
#  13000000,
#  13000000,
#  12900000,
#  12900000,
#  12900000,
#  12700000,
#  12700000,
#  12600000,
#  12500000,
#  12500000,
#  12000000,
#  12000000,
#  12000000,
#  11900000,
#  11800000,
#  11800000,
#  11800000,
#  11800000,
#  11700000,
#  11700000,
#  11700000,
#  11500000,
#  11500000,
#  11500000,
#  11500000,
#  11500000,
#  11500000,
#  11200000,
#  11000000,
#  11000000,
#  11000000,
#  10900000,
#  10900000,
#  10900000,
#  10750000,
#  10700000,
#  10700000,
#  10700000,
#  10700000,
#  10500000,
#  10200000,
#  10000000,
#  10000000,
#  9900000,
# ...

# %%
data.shape
# Out:
# (14864, 8)

# %%
data.head(1)
# Out:
#         Brand model  Age  kmDriven Transmission   Owner FuelType   Price
# 0  Volkswagen  Polo    4         1       Manual  second   Petrol  675000

# %%
data['FuelType'].unique()
# Out:
# array(['Petrol', 'Diesel', 'Hybrid/CNG'], dtype=object)

# %%
data['FuelType'] = data['FuelType'].map({'Petrol':0,'Diesel':1,'Hybrid/CNG':2})

# %%
data['FuelType'].unique()
# Out:
# array([0, 1, 2])

# %%
data['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
data['Transmission'] =data['Transmission'].map({'Manual':0,'Automatic':1})

# %%
data.head()
# Out:
#            Brand     model  Age  kmDriven  Transmission   Owner  FuelType  \
# 0     Volkswagen      Polo    4         1             0  second         0
# 1  Maruti Suzuki    Baleno    7         1             0  second         0
# 2        Hyundai     Verna    9         1             0  second         1
# 3           Audi        A4   13         1             1  second         1
# 4         Toyota  Fortuner   14         1             0  second         1
#
#      Price
# 0   675000
# 1   630000
# 2   465000
# 3   899000
# 4  1125000

# %%
X = data.drop(['model','Price'],axis=1)
y = data['Price']

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
X_train = pd.get_dummies(X_train, drop_first=True)
X_test = pd.get_dummies(X_test, drop_first=True)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
xgb = GradientBoostingRegressor()
xgb.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
xg = XGBRegressor()
xg.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
# Align X_test with X_train columns
X_test_aligned = X_test.reindex(columns=X_train.columns, fill_value=0)

# Make predictions
y_pred1 = lr.predict(X_test_aligned)
y_pred2 = rf.predict(X_test_aligned)
y_pred3 = xgb.predict(X_test_aligned)
y_pred4 = xg.predict(X_test_aligned)

# %%
from sklearn import metrics

# %%
score1 = metrics.r2_score(y_test,y_pred1)
score2 = metrics.r2_score(y_test,y_pred2)
score3 = metrics.r2_score(y_test,y_pred3)
score4 = metrics.r2_score(y_test,y_pred4)

# %%
print(score1,score2,score3,score4)
# Out:
# 0.41849183631551334 0.5670976754537881 0.5751453450976342 0.5962773561477661

# %%
final_data = pd.DataFrame({'Models':['LR','RF','GBR','XG'],
             "R2_SCORE":[score1,score2,score3,score4]})

# %%
final_data
# Out:
#   Models  R2_SCORE
# 0     LR  0.418492
# 1     RF  0.567098
# 2    GBR  0.575145
# 3     XG  0.596277

# %%
# Convert object columns to one-hot encoding
X_encoded = pd.get_dummies(X, columns=['Brand', 'Owner'], drop_first=True)

# Fit the model with the transformed data
xg = XGBRegressor()
xg_final = xg.fit(X_encoded, y)

# %%
import joblib

# %%
joblib.dump(xg_final,'car_price_predictor.pkl')
# Out:
# ['car_price_predictor.pkl']

# %%
model = joblib.load('car_price_predictor.pkl')

# %%
import pandas as pd
data_new = pd.DataFrame({
    'Price':3.26,
        'kmDriven':27000,
            'FuelType':0,
                'Transmission':0,
                    'Owner':0,
                        'Age':8
                        },index=[0])

# %%
# Add a placeholder 'Brand' column to data_new to match the training data structure
data_new['Brand'] = 'Unknown'  # Replace 'Unknown' with a default value if needed

# Align data_new with the features used in training
data_new_processed = pd.get_dummies(data_new, columns=['Brand', 'Owner'], drop_first=True)
data_new_processed = data_new_processed.reindex(columns=X_encoded.columns, fill_value=0)

# Make prediction
model.predict(data_new_processed)
# Out:
# array([516928.2], dtype=float32)

# %%
# Align X_test with X_train columns
X_test_aligned = X_test.reindex(columns=X_train.columns, fill_value=0)

# Train the model and evaluate
xgb_model = XGBRegressor()
xgb_model.fit(X_train, y_train)
xgb_model.score(X_test_aligned, y_test)
# Out:
# 0.5962773561477661

# %%
sns.boxplot(data['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Transmission', y='Price', data=data)
plt.title('Average Price by Car Brand')
plt.xlabel('Transmission Type: 0- Automatic, 1- Manual')
plt.ylabel('Average Price (₹)')
plt.xticks(rotation=0)
plt.show()
